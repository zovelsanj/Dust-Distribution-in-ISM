# %%
import numpy as np
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
# %matplotlib inline

# %%
CURR_DIR = os.getcwd()
data_files = glob.glob(CURR_DIR + "/**/*.csv")
df = pd.read_csv(data_files[2])

# %% [markdown]
# # Gaussian Fit for Temparature

# %% [markdown]
# $f(x) = \frac{1}{\sqrt{2\pi\sigma}}exp(\frac{x-\hat x}{2 \sigma})$

# %%
#np.random.seed(19680801)

# example data
mu = np.mean(df.Temp)  # mean of distribution
sigma = np.std(df.Temp)  # standard deviation of distribution
x = df.Temp

num_bins = 100
plt.figure(figsize = [8,6])
fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(x, num_bins, density=True, color = 'r')

# add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
ax.plot(bins, y, '--', color = 'k', lw = 3)
ax.set_xlabel('Temperature (K)', fontsize =14)
ax.set_ylabel('Probability density', fontsize = 14)
#ax.set_title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
# fig.savefig('Figure/GaTemp1.png', dpi = 400)
plt.show()

# %%
len(bins)
# Out:
# 101

# %% [markdown]
# # Gaussian Fit for Mass

# %%
#mkdir Figure

# %%
#np.random.seed(19680801)

# example data
mu = np.mean(df.Mass)  # mean of distribution
sigma = np.std(df.Mass)  # standard deviation of distribution
x = df.Mass

num_bins = 30
plt.figure(figsize = [8,6])
fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(x, num_bins, density=True, color = 'r')

# add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
ax.plot(bins, y, '--',color = 'k', lw = 3)
ax.set_xlabel('Mass (Kg)', fontsize = 14)
ax.set_ylabel('Probability density', fontsize = 14)
#ax.set_title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
# fig.savefig('Figure/GaMass.png', dpi = 400)
plt.show()

# %% [markdown]
# # Gaussian Fit for 60 $\mu$m Flux Density

# %%
np.random.seed(19680801)

# example data
mu = np.mean(df.f90)  # mean of distribution
sigma = np.std(df.f90)  # standard deviation of distribution
x = df.f90

num_bins = 100
plt.figure(figsize = [8,6])
fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(x, num_bins, density=True, color = 'r')

# add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
ax.plot(bins, y, '--', color = 'k', lw = 3)
ax.set_xlabel('Relative Flux Density at 60 $\mu$m', fontsize = 14)
ax.set_ylabel('Probability density', fontsize = 14)
#ax.set_title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
fig.savefig('Figure/GaF60.png', dpi = 300)
plt.show()

# %% [markdown]
# # Gaussian Fit for 100 $\mu$m Flux Density

# %%
#np.random.seed(19680801)

# example data
mu = np.mean(df.f100)  # mean of distribution
sigma = np.std(df.f100)  # standard deviation of distribution
x = df.f100

num_bins = 30
plt.figure(figsize = [8,6])
fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(x, num_bins, density=True, color = 'r')

# add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
ax.plot(bins, y, '--', color = 'k', lw = 3)
ax.set_xlabel('Relative Flux Density at 100 $\mu$m', fontsize = 14)
ax.set_ylabel('Probability density', fontsize = 14)
#ax.set_title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
fig.savefig('Figure/GaF100.png', dpi = 400)
plt.show()

# %%
'''from scipy import optimize
mu = np.mean(df.f100)  # mean of distribution
sigma = np.std(df.f100)  # standard deviation of distribution
data = df.f100

def gaussian(x, amplitude, mean, stddev):
    return amplitude * np.exp(-((x - mu) / 4 / sigma)**2)
popt, _ = optimize.curve_fit(gaussian, x, data)'''
# Out:
# 'from scipy import optimize\nmu = np.mean(df.f100)  # mean of distribution\nsigma = np.std(df.f100)  # standard deviation of distribution\ndata = df.f100\n\ndef gaussian(x, amplitude, mean, stddev):\n    return amplitude * np.exp(-((x - mu) / 4 / sigma)**2)\npopt, _ = optimize.curve_fit(gaussian, x, data)'
